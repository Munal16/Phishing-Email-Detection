# %%
import pandas as pd
# !pip install huggingface_hub
df = pd.read_csv("hf://datasets/zefang-liu/phishing-email-dataset/Phishing_Email.csv")

# %%
df
# Out:
#        Unnamed: 0                                         Email Text  \
# 0               0  re : 6 . 1100 , disc : uniformitarianism , re ...
# 1               1  the other side of * galicismos * * galicismo *...
# 2               2  re : equistar deal tickets are you still avail...
# 3               3  \nHello I am your hot lil horny toy.\n    I am...
# 4               4  software at incredibly low prices ( 86 % lower...
# ...           ...                                                ...
# 18645       18646  date a lonely housewife always wanted to date ...
# 18646       18647  request submitted : access request for anita ....
# 18647       18648  re : important - prc mtg hi dorn & john , as y...
# 18648       18649  press clippings - letter on californian utilit...
# 18649       18650                                              empty
#
#            Email Type
# 0          Safe Email
# 1          Safe Email
# 2          Safe Email
# 3      Phishing Email
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                                         Email Text  \
# 0           0  re : 6 . 1100 , disc : uniformitarianism , re ...
# 1           1  the other side of * galicismos * * galicismo *...
# 2           2  re : equistar deal tickets are you still avail...
# 3           3  \nHello I am your hot lil horny toy.\n    I am...
# 4           4  software at incredibly low prices ( 86 % lower...
#
#        Email Type
# 0      Safe Email
# 1      Safe Email
# 2      Safe Email
# 3  Phishing Email
# 4  Phishing Email

# %%
toxic_non_toxic_counts = df['Email Type'].value_counts()
print(toxic_non_toxic_counts)
# Out:
# Email Type
# Safe Email        11322
# Phishing Email     7328
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x='Email Type')
plt.title("Class Distribution of Email Types")
plt.xlabel("Email Category")
plt.ylabel("Number of Emails")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Set the style and color palette
sns.set_style("whitegrid")
plt.figure(figsize=(12, 7))

# Create color palette - vibrant and modern
colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#FFA07A', '#98D8C8']

# Count plot with enhanced styling
ax = sns.countplot(data=df, x='Email Type', palette=colors, 
                   edgecolor='white', linewidth=2)

# Add value labels on top of each bar
for container in ax.containers:
    ax.bar_label(container, fontsize=11, fontweight='bold', padding=5)

# Customize the plot
plt.title("Distribution of Email Types", fontsize=18, fontweight='bold', pad=20)
plt.xlabel("Email Category", fontsize=14, fontweight='bold')
plt.ylabel("Number of Emails", fontsize=14, fontweight='bold')

# Rotate x-axis labels if needed
plt.xticks(rotation=45, ha='right', fontsize=11)
plt.yticks(fontsize=11)

# Add grid for better readability
ax.grid(axis='y', alpha=0.3, linestyle='--', linewidth=0.7)
ax.set_axisbelow(True)

# Remove top and right spines for cleaner look
sns.despine()

# Tight layout to prevent label cutoff
plt.tight_layout()
plt.show()
# Out:
# C:\Users\opban\AppData\Local\Temp\ipykernel_16520\1725108687.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='Email Type', palette=colors,
# C:\Users\opban\AppData\Local\Temp\ipykernel_16520\1725108687.py:13: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   ax = sns.countplot(data=df, x='Email Type', palette=colors,
